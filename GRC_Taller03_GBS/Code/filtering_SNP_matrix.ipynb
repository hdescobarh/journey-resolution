# %% [markdown]
# # Taller 3. Filtrado de marcadores moleculares tipo SNP
# Genética de rasgos complejos 2024-01 - Docente Johana Carolina Soto Sedano
#
# __Hans D. Escobar H.__

# %%
from pathlib import Path
import pandas as pd

# %%
data_path = Path("../Private_Data/GBS.txt")
raw_df = pd.read_csv(str(data_path), sep="\t", index_col=0, dtype=str)
raw_df.head(n=3)
# Out:
#      alleles       chrom      pos strand assembly center protLSID assayLSID  \
# rs
# SNP1     C/T  ST4.03ch01  2597267      +      NaN    NaN      NaN       NaN
# SNP2     A/G  ST4.03ch01  2631717      +      NaN    NaN      NaN       NaN
# SNP3     C/A  ST4.03ch01  2631718      +      NaN    NaN      NaN       NaN
#
#      panelLSID QCcode  ... G141 G142 G143 G144 G145 G146 G147 G148 G149 G150
# rs                     ...
# SNP1       NaN    NaN  ...   CC   CC   CC   CC   CC   CC   CC   CC   CC   CC
# SNP2       NaN    NaN  ...   AG   AA   AA   AA   AA   AA   AA   AA   AA   AA
# SNP3       NaN    NaN  ...   CC   CC   CC   CC   CC   CC   CC   CC   CC   CC
#
# [3 rows x 160 columns]

# %%
width = 10
for line in range(0, len(raw_df.columns), width):
    print("{}".format(list(raw_df.columns[line : line + width])))
# Out:
# ['alleles', 'chrom', 'pos', 'strand', 'assembly', 'center', 'protLSID', 'assayLSID', 'panelLSID', 'QCcode']
# ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10']
# ['G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 'G18', 'G19', 'G20']
# ['G21', 'G22', 'G23', 'G24', 'G25', 'G26', 'G27', 'G28', 'G29', 'G30']
# ['G31', 'G32', 'G33', 'G34', 'G35', 'G36', 'G37', 'G38', 'G39', 'G40']
# ['G41', 'G42', 'G43', 'G44', 'G45', 'G46', 'G47', 'G48', 'G49', 'G50']
# ['G51', 'G52', 'G53', 'G54', 'G55', 'G56', 'G57', 'G58', 'G59', 'G60']
# ['G61', 'G62', 'G63', 'G64', 'G65', 'G66', 'G67', 'G68', 'G69', 'G70']
# ['G71', 'G72', 'G73', 'G74', 'G75', 'G76', 'G77', 'G78', 'G79', 'G80']
# ['G81', 'G82', 'G83', 'G84', 'G85', 'G86', 'G87', 'G88', 'G89', 'G90']
# ['G91', 'G92', 'G93', 'G94', 'G95', 'G96', 'G97', 'G98', 'G99', 'G100']
# ['G101', 'G102', 'G103', 'G104', 'G105', 'G106', 'G107', 'G108', 'G109', 'G110']
# ['G111', 'G112', 'G113', 'G114', 'G115', 'G116', 'G117', 'G118', 'G119', 'G120']
# ['G121', 'G122', 'G123', 'G124', 'G125', 'G126', 'G127', 'G128', 'G129', 'G130']
# ['G131', 'G132', 'G133', 'G134', 'G135', 'G136', 'G137', 'G138', 'G139', 'G140']
# ['G141', 'G142', 'G143', 'G144', 'G145', 'G146', 'G147', 'G148', 'G149', 'G150']

# %% [markdown]
# Removiendo marcadores con datos perdidos

# %%
def missing_allele_filter(df, threshold=0.85):
    def filter_NN_and_NaN(row):
        counts = row.iloc[10:].value_counts(normalize=True, dropna=False)
        return counts.get("NN", 0) + counts.get(pd.NA, 0) < threshold

    return df[df.apply(filter_NN_and_NaN, axis=1)]

# %%
test_df = raw_df.head(50)

# %%
missing_allele_filter(test_df)
# Out:
#       alleles       chrom       pos strand  assembly  center  protLSID  \
# rs
# SNP1      C/T  ST4.03ch01   2597267      +       NaN     NaN       NaN
# SNP2      A/G  ST4.03ch01   2631717      +       NaN     NaN       NaN
# SNP3      C/A  ST4.03ch01   2631718      +       NaN     NaN       NaN
# SNP4      G/A  ST4.03ch01   2631725      +       NaN     NaN       NaN
# SNP5      C/T  ST4.03ch01   2631732      +       NaN     NaN       NaN
# SNP6      G/A  ST4.03ch01   2631734      +       NaN     NaN       NaN
# SNP7      A/G  ST4.03ch01   3683816      +       NaN     NaN       NaN
# SNP8      T/C  ST4.03ch01   5061238      +       NaN     NaN       NaN
# SNP9      G/A  ST4.03ch01   5452459      +       NaN     NaN       NaN
# SNP10     A/C  ST4.03ch01   5452472      +       NaN     NaN       NaN
# SNP11     C/T  ST4.03ch01   6054828      +       NaN     NaN       NaN
# SNP12     G/T  ST4.03ch01   6054832      +       NaN     NaN       NaN
# SNP13     A/C  ST4.03ch01   6054851      +       NaN     NaN       NaN
# SNP14     G/A  ST4.03ch01   6081955      +       NaN     NaN       NaN
# SNP15     C/T  ST4.03ch01   7870820      +       NaN     NaN       NaN
# SNP16     C/A  ST4.03ch01   8243554      +       NaN     NaN       NaN
# SNP17     G/A  ST4.03ch01   8616122      +       NaN     NaN       NaN
# SNP18     G/A  ST4.03ch01   8616127      +       NaN     NaN       NaN
# SNP19     A/C  ST4.03ch01   8768561      +       NaN     NaN       NaN
# SNP20     T/C  ST4.03ch01   8768563      +       NaN     NaN       NaN
# SNP21     G/T  ST4.03ch01   8768565      +       NaN     NaN       NaN
# SNP22     G/A  ST4.03ch01   8945651      +       NaN     NaN       NaN
# SNP23     G/A  ST4.03ch01   8945658      +       NaN     NaN       NaN
# SNP24     G/A  ST4.03ch01  10420384      +       NaN     NaN       NaN
# SNP25     C/T  ST4.03ch01  10420388      +       NaN     NaN       NaN
# SNP26     G/A  ST4.03ch01  10420405      +       NaN     NaN       NaN
# SNP27     G/A  ST4.03ch01  10668193      +       NaN     NaN       NaN
# SNP28     G/A  ST4.03ch01  10668210      +       NaN     NaN       NaN
# SNP29     C/T  ST4.03ch01  12296160      +       NaN     NaN       NaN
# SNP30     G/A  ST4.03ch01  12842080      +       NaN     NaN       NaN
# SNP31     C/T  ST4.03ch01  13623042      +       NaN     NaN       NaN
# SNP32     G/A  ST4.03ch01  16081059      +       NaN     NaN       NaN
# SNP33     G/A  ST4.03ch01  16081060      +       NaN     NaN       NaN
# SNP34     C/T  ST4.03ch01  16081080      +       NaN     NaN       NaN
# SNP35     G/T  ST4.03ch01  16335086      +       NaN     NaN       NaN
# SNP36     G/C  ST4.03ch01  16335096      +       NaN     NaN       NaN
# SNP37     A/G  ST4.03ch01  16902052      +       NaN     NaN       NaN
# SNP38     C/T  ST4.03ch01  17169607      +       NaN     NaN       NaN
# SNP39     G/A  ST4.03ch01  17169611      +       NaN     NaN       NaN
# SNP40     C/T  ST4.03ch01  17169619      +       NaN     NaN       NaN
# SNP41     G/A  ST4.03ch01  17233535      +       NaN     NaN       NaN
# SNP42     A/T  ST4.03ch01  17233555      +       NaN     NaN       NaN
# SNP43     A/G  ST4.03ch01  17233558      +       NaN     NaN       NaN
# SNP44     A/T  ST4.03ch01  17233563      +       NaN     NaN       NaN
# SNP45     T/C  ST4.03ch01  17932043      +       NaN     NaN       NaN
# SNP46     T/C  ST4.03ch01  17932046      +       NaN     NaN       NaN
# SNP47     C/T  ST4.03ch01  17932048      +       NaN     NaN       NaN
# SNP48     T/C  ST4.03ch01  17932068      +       NaN     NaN       NaN
# SNP49     G/T  ST4.03ch01  19770089      +       NaN     NaN       NaN
# SNP50     C/T  ST4.03ch01  22081862      +       NaN     NaN       NaN
#
#        assayLSID  panelLSID  QCcode  ... G141 G142 G143 G144 G145 G146 G147  \
# rs                                   ...
# SNP1         NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP2         NaN        NaN     NaN  ...   AG   AA   AA   AA   AA   AA   AA
# SNP3         NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP4         NaN        NaN     NaN  ...   GA   GG   GG   GG   GG   GG   GG
# SNP5         NaN        NaN     NaN  ...   CT   TT   TT   TT   TT   TT   TT
# SNP6         NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP7         NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP8         NaN        NaN     NaN  ...   TT   TT   TT   TT   TT   TT   TT
# SNP9         NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP10        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP11        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP12        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP13        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP14        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   NN   GG
# SNP15        NaN        NaN     NaN  ...   CC   CC   CC   CT   CC   CC   CC
# SNP16        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP17        NaN        NaN     NaN  ...   AA   GA   NN   AA   AA   AA   AA
# SNP18        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP19        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP20        NaN        NaN     NaN  ...   TT   TT   TT   TT   TT   TT   TT
# SNP21        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP22        NaN        NaN     NaN  ...   GA   GA   GG   GA   NN   GA   GA
# SNP23        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP24        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP25        NaN        NaN     NaN  ...   CT   CC   CC   CC   CC   CC   CC
# SNP26        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP27        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP28        NaN        NaN     NaN  ...   GG   GG   GA   GA   GG   GA   GA
# SNP29        NaN        NaN     NaN  ...   CT   CT   CT   CC   CT   CC   CC
# SNP30        NaN        NaN     NaN  ...   GA   GA   GA   GG   GA   GG   GG
# SNP31        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP32        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP33        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP34        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP35        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP36        NaN        NaN     NaN  ...   GG   GG   GG   GG   NN   GG   GG
# SNP37        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP38        NaN        NaN     NaN  ...   CT   CT   NN   CT   CC   CT   CT
# SNP39        NaN        NaN     NaN  ...   GA   GA   GA   GG   GA   GG   GG
# SNP40        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP41        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP42        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP43        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP44        NaN        NaN     NaN  ...   AT   AT   AT   AT   AT   AT   AT
# SNP45        NaN        NaN     NaN  ...   TT   TC   TT   TT   TT   TT   TT
# SNP46        NaN        NaN     NaN  ...   TT   TC   TT   TT   TT   TT   TT
# SNP47        NaN        NaN     NaN  ...   CC   CT   CC   CC   CC   CC   CC
# SNP48        NaN        NaN     NaN  ...   TT   TT   TT   TT   TT   TT   TT
# SNP49        NaN        NaN     NaN  ...   GG   GG   GG   GG   NN   GG   GG
# SNP50        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
#
#       G148 G149 G150
# rs
# SNP1    CC   CC   CC
# SNP2    AA   AA   AA
# SNP3    CC   CC   CC
# SNP4    GG   GG   GG
# SNP5    TT   CT   TT
# SNP6    GG   GA   GG
# SNP7    AA   AA   AA
# SNP8    TT   TT   TT
# SNP9    GG   GG   GG
# SNP10   AA   AA   AA
# SNP11   CC   CC   CC
# SNP12   GG   GG   GG
# SNP13   AA   AA   AA
# SNP14   GG   GG   GG
# SNP15   CC   CC   CC
# SNP16   CC   CC   CC
# SNP17   AA   GA   GA
# SNP18   GG   GG   GG
# SNP19   AA   AA   AA
# SNP20   TT   TT   TT
# SNP21   GG   GG   GG
# SNP22   GA   GA   GA
# SNP23   GG   GG   GG
# SNP24   GG   GG   GG
# SNP25   CC   CC   CC
# SNP26   GG   GG   GG
# SNP27   GG   GG   GG
# SNP28   GA   GG   GA
# SNP29   CC   CC   CT
# SNP30   GG   GG   GG
# SNP31   CC   CC   CC
# SNP32   GG   GG   GG
# SNP33   GG   GG   GG
# SNP34   CC   CC   CC
# SNP35   GG   GG   GG
# SNP36   GG   GG   GG
# SNP37   AA   AA   AA
# SNP38   CC   CT   CC
# SNP39   GG   GG   GG
# SNP40   CC   CC   CC
# SNP41   GG   GG   GG
# SNP42   AA   AA   AA
# SNP43   AA   AA   AA
# SNP44   AT   AT   AT
# SNP45   TT   TC   TT
# SNP46   TT   TC   TT
# SNP47   CC   CT   CC
# SNP48   TT   TT   TT
# SNP49   GG   GG   GG
# SNP50   CC   CC   CC
#
# [50 rows x 160 columns]

# %% [markdown]
# Remueve marcadores no informativos. En este caso, duplicados con segregación idéntica.

# %%
def identical_segregation_filter(df):
    return df.drop_duplicates(subset=test_df.columns[10:])

# %%
identical_segregation_filter(test_df)
# Out:
#       alleles       chrom       pos strand  assembly  center  protLSID  \
# rs
# SNP1      C/T  ST4.03ch01   2597267      +       NaN     NaN       NaN
# SNP2      A/G  ST4.03ch01   2631717      +       NaN     NaN       NaN
# SNP3      C/A  ST4.03ch01   2631718      +       NaN     NaN       NaN
# SNP4      G/A  ST4.03ch01   2631725      +       NaN     NaN       NaN
# SNP5      C/T  ST4.03ch01   2631732      +       NaN     NaN       NaN
# SNP6      G/A  ST4.03ch01   2631734      +       NaN     NaN       NaN
# SNP7      A/G  ST4.03ch01   3683816      +       NaN     NaN       NaN
# SNP8      T/C  ST4.03ch01   5061238      +       NaN     NaN       NaN
# SNP9      G/A  ST4.03ch01   5452459      +       NaN     NaN       NaN
# SNP10     A/C  ST4.03ch01   5452472      +       NaN     NaN       NaN
# SNP11     C/T  ST4.03ch01   6054828      +       NaN     NaN       NaN
# SNP12     G/T  ST4.03ch01   6054832      +       NaN     NaN       NaN
# SNP14     G/A  ST4.03ch01   6081955      +       NaN     NaN       NaN
# SNP15     C/T  ST4.03ch01   7870820      +       NaN     NaN       NaN
# SNP16     C/A  ST4.03ch01   8243554      +       NaN     NaN       NaN
# SNP17     G/A  ST4.03ch01   8616122      +       NaN     NaN       NaN
# SNP18     G/A  ST4.03ch01   8616127      +       NaN     NaN       NaN
# SNP19     A/C  ST4.03ch01   8768561      +       NaN     NaN       NaN
# SNP20     T/C  ST4.03ch01   8768563      +       NaN     NaN       NaN
# SNP21     G/T  ST4.03ch01   8768565      +       NaN     NaN       NaN
# SNP22     G/A  ST4.03ch01   8945651      +       NaN     NaN       NaN
# SNP23     G/A  ST4.03ch01   8945658      +       NaN     NaN       NaN
# SNP24     G/A  ST4.03ch01  10420384      +       NaN     NaN       NaN
# SNP25     C/T  ST4.03ch01  10420388      +       NaN     NaN       NaN
# SNP26     G/A  ST4.03ch01  10420405      +       NaN     NaN       NaN
# SNP27     G/A  ST4.03ch01  10668193      +       NaN     NaN       NaN
# SNP28     G/A  ST4.03ch01  10668210      +       NaN     NaN       NaN
# SNP29     C/T  ST4.03ch01  12296160      +       NaN     NaN       NaN
# SNP30     G/A  ST4.03ch01  12842080      +       NaN     NaN       NaN
# SNP31     C/T  ST4.03ch01  13623042      +       NaN     NaN       NaN
# SNP32     G/A  ST4.03ch01  16081059      +       NaN     NaN       NaN
# SNP33     G/A  ST4.03ch01  16081060      +       NaN     NaN       NaN
# SNP34     C/T  ST4.03ch01  16081080      +       NaN     NaN       NaN
# SNP35     G/T  ST4.03ch01  16335086      +       NaN     NaN       NaN
# SNP36     G/C  ST4.03ch01  16335096      +       NaN     NaN       NaN
# SNP37     A/G  ST4.03ch01  16902052      +       NaN     NaN       NaN
# SNP38     C/T  ST4.03ch01  17169607      +       NaN     NaN       NaN
# SNP39     G/A  ST4.03ch01  17169611      +       NaN     NaN       NaN
# SNP40     C/T  ST4.03ch01  17169619      +       NaN     NaN       NaN
# SNP41     G/A  ST4.03ch01  17233535      +       NaN     NaN       NaN
# SNP42     A/T  ST4.03ch01  17233555      +       NaN     NaN       NaN
# SNP43     A/G  ST4.03ch01  17233558      +       NaN     NaN       NaN
# SNP44     A/T  ST4.03ch01  17233563      +       NaN     NaN       NaN
# SNP45     T/C  ST4.03ch01  17932043      +       NaN     NaN       NaN
# SNP46     T/C  ST4.03ch01  17932046      +       NaN     NaN       NaN
# SNP47     C/T  ST4.03ch01  17932048      +       NaN     NaN       NaN
# SNP48     T/C  ST4.03ch01  17932068      +       NaN     NaN       NaN
# SNP49     G/T  ST4.03ch01  19770089      +       NaN     NaN       NaN
# SNP50     C/T  ST4.03ch01  22081862      +       NaN     NaN       NaN
#
#        assayLSID  panelLSID  QCcode  ... G141 G142 G143 G144 G145 G146 G147  \
# rs                                   ...
# SNP1         NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP2         NaN        NaN     NaN  ...   AG   AA   AA   AA   AA   AA   AA
# SNP3         NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP4         NaN        NaN     NaN  ...   GA   GG   GG   GG   GG   GG   GG
# SNP5         NaN        NaN     NaN  ...   CT   TT   TT   TT   TT   TT   TT
# SNP6         NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP7         NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP8         NaN        NaN     NaN  ...   TT   TT   TT   TT   TT   TT   TT
# SNP9         NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP10        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP11        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP12        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP14        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   NN   GG
# SNP15        NaN        NaN     NaN  ...   CC   CC   CC   CT   CC   CC   CC
# SNP16        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP17        NaN        NaN     NaN  ...   AA   GA   NN   AA   AA   AA   AA
# SNP18        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP19        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP20        NaN        NaN     NaN  ...   TT   TT   TT   TT   TT   TT   TT
# SNP21        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP22        NaN        NaN     NaN  ...   GA   GA   GG   GA   NN   GA   GA
# SNP23        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP24        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP25        NaN        NaN     NaN  ...   CT   CC   CC   CC   CC   CC   CC
# SNP26        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP27        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP28        NaN        NaN     NaN  ...   GG   GG   GA   GA   GG   GA   GA
# SNP29        NaN        NaN     NaN  ...   CT   CT   CT   CC   CT   CC   CC
# SNP30        NaN        NaN     NaN  ...   GA   GA   GA   GG   GA   GG   GG
# SNP31        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP32        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP33        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP34        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP35        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP36        NaN        NaN     NaN  ...   GG   GG   GG   GG   NN   GG   GG
# SNP37        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP38        NaN        NaN     NaN  ...   CT   CT   NN   CT   CC   CT   CT
# SNP39        NaN        NaN     NaN  ...   GA   GA   GA   GG   GA   GG   GG
# SNP40        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
# SNP41        NaN        NaN     NaN  ...   GG   GG   GG   GG   GG   GG   GG
# SNP42        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP43        NaN        NaN     NaN  ...   AA   AA   AA   AA   AA   AA   AA
# SNP44        NaN        NaN     NaN  ...   AT   AT   AT   AT   AT   AT   AT
# SNP45        NaN        NaN     NaN  ...   TT   TC   TT   TT   TT   TT   TT
# SNP46        NaN        NaN     NaN  ...   TT   TC   TT   TT   TT   TT   TT
# SNP47        NaN        NaN     NaN  ...   CC   CT   CC   CC   CC   CC   CC
# SNP48        NaN        NaN     NaN  ...   TT   TT   TT   TT   TT   TT   TT
# SNP49        NaN        NaN     NaN  ...   GG   GG   GG   GG   NN   GG   GG
# SNP50        NaN        NaN     NaN  ...   CC   CC   CC   CC   CC   CC   CC
#
#       G148 G149 G150
# rs
# SNP1    CC   CC   CC
# SNP2    AA   AA   AA
# SNP3    CC   CC   CC
# SNP4    GG   GG   GG
# SNP5    TT   CT   TT
# SNP6    GG   GA   GG
# SNP7    AA   AA   AA
# SNP8    TT   TT   TT
# SNP9    GG   GG   GG
# SNP10   AA   AA   AA
# SNP11   CC   CC   CC
# SNP12   GG   GG   GG
# SNP14   GG   GG   GG
# SNP15   CC   CC   CC
# SNP16   CC   CC   CC
# SNP17   AA   GA   GA
# SNP18   GG   GG   GG
# SNP19   AA   AA   AA
# SNP20   TT   TT   TT
# SNP21   GG   GG   GG
# SNP22   GA   GA   GA
# SNP23   GG   GG   GG
# SNP24   GG   GG   GG
# SNP25   CC   CC   CC
# SNP26   GG   GG   GG
# SNP27   GG   GG   GG
# SNP28   GA   GG   GA
# SNP29   CC   CC   CT
# SNP30   GG   GG   GG
# SNP31   CC   CC   CC
# SNP32   GG   GG   GG
# SNP33   GG   GG   GG
# SNP34   CC   CC   CC
# SNP35   GG   GG   GG
# SNP36   GG   GG   GG
# SNP37   AA   AA   AA
# SNP38   CC   CT   CC
# SNP39   GG   GG   GG
# SNP40   CC   CC   CC
# SNP41   GG   GG   GG
# SNP42   AA   AA   AA
# SNP43   AA   AA   AA
# SNP44   AT   AT   AT
# SNP45   TT   TC   TT
# SNP46   TT   TC   TT
# SNP47   CC   CT   CC
# SNP48   TT   TT   TT
# SNP49   GG   GG   GG
# SNP50   CC   CC   CC
#
# [49 rows x 160 columns]

# %%
# Estimation of Minor allele frequency from called genotypes
def maf_from_called_filter(df, threshold=0.05):
    def filter_NN_and_NaN(row):
        counts = row.iloc[10:].value_counts(normalize=True, dropna=False)
        return counts.get("NN", 0) + counts.get(pd.NA, 0) < threshold

# %%
str(test_df.iloc[0, 0]).split("/")
# Out:
# ['C', 'T']

# %%
test_df.iloc[0, 10:].value_counts(dropna=True)
# Out:
# SNP1
# CC    144
# NN      3
# CT      3
# Name: count, dtype: int64
